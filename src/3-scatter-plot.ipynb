# %% [markdown]
# ### Exercise 3: Scatter Plot with Annotations

# %%
# TASK: Create a scatter plot with x = [1, 2, 3, 4, 5] and y = [2, 4, 6, 8, 10].
# Annotate each point with its (x, y) value, and set the title as 'Scatter Plot with Annotations'.

# %%
def create_scatter_plot(x, y):
    try:
        if x is None or y is None or not x or not y:
            raise ValueError("Inputs x and y cannot be None or empty.")
        if len(x) != len(y):
            raise ValueError("x and y must have the same length.")
        if not all(isinstance(i, (int, float)) for i in x + y):
            raise TypeError("x and y must contain only numeric values.")
        
        plt.figure(figsize=(10, 6))
        plt.scatter(x, y, color='purple')
        for i, (xi, yi) in enumerate(zip(x, y)):
            plt.text(xi, yi, f'({xi},{yi})')
        plt.title('Scatter Plot with Annotations')
        plt.xlabel('X-axis')
        plt.ylabel('Y-axis')
        plt.grid(True)
        plt.show()
    except Exception as e:
        print(f"Error: {e}")

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
create_scatter_plot(x, y)

# %% [markdown]
# successfully created scatter plot with annotations
